# %% [markdown]
# <a href="https://colab.research.google.com/github/citydataviz/FastCampus/blob/main/%08(%E1%84%80%E1%85%AA%E1%84%8C%E1%85%A6)_%E1%84%83%E1%85%A6%E1%84%8B%E1%85%B5%E1%84%90%E1%85%A5%E1%84%87%E1%85%AE%E1%86%AB%E1%84%89%E1%85%A5%E1%86%A8_%E1%84%91%E1%85%B5%E1%86%AF%E1%84%89%E1%85%AE%E1%84%85%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%87%E1%85%B3%E1%84%85%E1%85%A5%E1%84%85%E1%85%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 콜랩 샘플 데이터 불러오기
#
# - california_housing_test.csv 파일을 읽어보자.
# - pandas 라이브러리를 pd로 수정해서 사용
# - 힌트: pd.read_csv 사용

# %%
# 데이터프레임을 df 변수이름으로 저장

# %%
# 첫번째 5개 행 읽기 (head)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
# 2. 기본 정보 확인 (info, describe)
# Out:
# 2. 데이터 기본 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB
#
# 데이터 통계 정보:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# ...

# %%
# 3. 위도(latitude)와 경도(latitude) 컬럼만 별도로 뽑아내기
# Out:
#       latitude  longitude
# 0        37.37    -122.05
# 1        34.26    -118.30
# 2        33.78    -117.81
# 3        33.82    -118.36
# 4        36.33    -119.67
# ...        ...        ...
# 2995     34.42    -119.86
# 2996     34.06    -118.14
# 2997     36.30    -119.70
# 2998     34.10    -117.12
# 2999     34.42    -119.63
#
# [3000 rows x 2 columns]

# %%
# 4. 조건부 필터링
# Out:
# 중간 주택 가격이 300,000달러 이상인 지역:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 18      -118.88     34.21                26.0       1590.0           196.0
# 19      -122.59     38.01                35.0       8814.0          1307.0
# 25      -118.03     34.16                36.0       1401.0           218.0
# ...         ...       ...                 ...          ...             ...
# 2983    -122.54     37.90                48.0       2491.0           460.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
# 5. 새로운 열 만들기
# 방당 인구수 계산
# Out:
# 방당 인구수를 추가한 데이터:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
# 7. 데이터 정렬
# Out:
# 주택 가격 기준 내림차순 정렬:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2999    -119.63     34.42                42.0       1765.0           263.0
# 2053    -122.25     37.45                34.0       2999.0           365.0
# 117     -122.07     37.34                30.0       1851.0           238.0
# 118     -117.18     33.02                15.0       3540.0           453.0
# 2152    -118.43     33.96                20.0       1901.0           270.0
# ...         ...       ...                 ...          ...             ...
# 2555    -122.06     37.39                22.0       1236.0           290.0
# 734     -117.65     35.00                36.0       1184.0           316.0
# 2740    -119.97     36.44                18.0       1128.0           237.0
# 1031    -123.08     40.40                10.0        365.0           102.0
# 2001    -117.16     32.71                52.0        845.0           451.0
#
# ...

# %% [markdown]
# ## 시각화 라이브러리 pygwalker
# - Tableau 와 유사한 기능을 파이썬에서 실행가능
# - Link: https://github.com/Kanaries/pygwalker

# %%
# pygwaker 설치 (pip install + 패키지)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 41.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.2/956.2 kB 46.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.7/213.7 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 37.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 80.4 MB/s eta 0:00:00
# ...

# %%
# 설치 후 import + 라이브러리명

import pygwalker as pyg
pyg.walk(df)
